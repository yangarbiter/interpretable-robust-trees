# %%
import sys
sys.path.append("../")

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rc('text', usetex=False)

import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import scipy

from rsep_explain.variables import auto_var
from utils import params_to_dataframe
from params import RiskSlimExperiments3, LinSepBBMRobExperiments3, RobDTInterpretRobExperiments3, DTInterpretRobExperiments3, XgboostRobDTInterpretRobExperiments
from IPython.display import display

fontsize = 16

# %%
def display_results(exp, result_file_dir='./results/calc_separation', columns=None):
    _, _, grid_params, _ = exp()()
    df = params_to_dataframe(grid_params,
                             columns=columns,
                             result_file_dir=result_file_dir,
                             logging_level=0)
    return df

# %%
def proc_bbm_result(df, rsep=0.1):
    depths, unique_clfs, accs, ers = [], [], [], []
    df = df.loc[df['rsep'] == rsep].copy()
    print(len(df))
    for i, d in df.iterrows():
        depths.append(d['bbm_results']['depth'])
        unique_clfs.append(len(set(d['bbm_results']['learned_model'])))
        accs.append(d['bbm_results']['tst acc'])
        ers.append(d['bbm_results']['er dist'].mean())
        
    df['depth'] = depths
    df['unique weak leaners'] = unique_clfs
    df['tst acc'] = accs
    df['rob'] = ers
    return df[['dataset', 'random_seed', 'depth', 'unique weak leaners', 'tst acc', 'rob']]

def proc_riskslim_result(df):
    depths, accs, ers = [], [], []
    for i, d in df.iterrows():
        depths.append((d['linsep_results'][0]['w'] != 0).sum())
        accs.append(d['linsep_results'][0]['tst acc'])
        ers.append(d['linsep_results'][0]['er dist'].mean())
        
    df['depth'] = depths
    df['tst acc'] = accs
    df['rob'] = ers
    return df[['dataset', 'random_seed', 'depth', 'tst acc', 'rob']]


def proc_dt_result(df):
    depths, accs, ers = [], [], []
    for i, d in df.iterrows():
        depths.append(d['best_clf'].tree_.node_count - d['best_clf'].tree_.n_leaves)
        #depths.append(d['best_clf'].tree_.node_count)
        #depths.append(d['best_clf'].tree_.n_leaves)
        accs.append(d['tst acc'])
        ers.append(d['er dist'])
        
    df['depth'] = depths
    df['tst acc'] = accs
    df['rob'] = ers
    return df[['dataset', 'random_seed', 'depth', 'tst acc', 'rob']]

from experiments.xgboostrobdt_interpret_rob import get_xgb_depth_leaves_nodes
def proc_xgb_result(df, rsep=0.1):
    depths, accs, ers = [], [], []
    df = df.loc[df['rsep'] == rsep].copy()
    for i, d in df.iterrows():
        _, leaves, nodes = get_xgb_depth_leaves_nodes(d['best_clf'])
        depths.append(nodes - leaves)
        accs.append(d['tst acc'])
        ers.append(d['er dist'].mean())
        
    df['depth'] = depths
    df['tst acc'] = accs
    df['rob'] = ers
    return df[['dataset', 'random_seed', 'depth', 'tst acc', 'rob']]

# %%
#df_bbm_ori = display_results(LinSepBBMRobExperiments3, '../results/bbm_rob_lin_noise_3/',['n_samples', 'bbm_results'])

# %%
df_bbm_ori_ori = display_results(LinSepBBMRobExperiments3, '../results/lin_sep_bbm_rob_3', ['n_samples', 'bbm_results'])

# %%
columns = ['dataset', 'random_seed', 'tst acc', 'unique weak leaners', 'rob']
column_names = ['dataset', 'random_seed', 'tst acc', 'depth', 'rob']
df_bbm = proc_bbm_result(df_bbm_ori_ori, rsep=0.05)
df_bbm = df_bbm[columns]
df_bbm.columns = column_names
df_bbm.groupby("dataset").mean()
# Out:
# 130
#                    random_seed   tst acc  depth       rob
# dataset
# risk_adult                 4.5  0.812274    6.0  0.500014
# risk_bank                  4.5  0.896300    8.0  0.500003
# risk_bank_2                4.5  0.896822    4.5  0.498001
# risk_breastcancer          4.5  0.957522   11.0  0.274703
# risk_careval               4.5  0.769702    8.7  0.495063
# risk_compasbin             4.5  0.662456    7.6  0.331743
# risk_diabetes              4.5  0.650000    2.1  0.145283
# risk_ficobin               4.5  0.721118   11.8  0.500044
# risk_heart                 4.5  0.822222    9.5  0.323431
# risk_ionosphere            4.5  0.856897    6.8  0.275112
# risk_mammo                 4.5  0.771384    1.9  0.495042
# risk_mushroom              4.5  0.966803    9.9  0.500047
# risk_spambase              4.5  0.788545    5.6  0.047710

# %%
columns = ['dataset', 'random_seed', 'tst acc', 'depth', 'rob']
column_names = ['dataset', 'random_seed', 'tst acc', 'depth', 'rob']
df = display_results(RiskSlimExperiments3, '../results/risk_slim_3', ['n_samples', 'linsep_results'])
df = proc_riskslim_result(df)
rudin_df = df[columns]
rudin_df.columns = column_names
rudin_df.groupby("dataset").mean()
# Out:
#                    random_seed   tst acc  depth       rob
# dataset
# risk_adult                 4.5  0.824195   14.9  0.123850
# risk_bank                  4.5  0.896447    8.9  0.198242
# risk_bank_2                4.5  0.899676   13.8  0.104087
# risk_breastcancer          4.5  0.957080    6.0  0.277423
# risk_careval               4.5  0.906305   10.1  0.190866
# risk_compasbin             4.5  0.651140    5.4  0.147302
# risk_diabetes              4.5  0.762598    6.0  0.092907
# risk_ficobin               4.5  0.713094    6.4  0.221749
# risk_heart                 4.5  0.816667   11.9  0.137193
# risk_ionosphere            4.5  0.878448   17.9  0.070969
# risk_mammo                 4.5  0.791509    7.2  0.213982
# risk_mushroom              4.5  0.999925   23.8  0.095776
# risk_spambase              4.5  0.881040   29.5  0.016140

# %%
columns = ['dataset', 'random_seed', 'tst acc', 'depth', 'rob']
column_names = ['dataset', 'random_seed', 'tst acc', 'depth', 'rob']
dt_df = display_results(DTInterpretRobExperiments3, '../results/dt_interpret_rob_3/', ['tst acc', 'adv tst dist', 'er dist', 'best_clf'])
dt_df = proc_dt_result(dt_df)
dt_df = dt_df[columns]
dt_df.columns = column_names
dt_df.groupby("dataset").mean()
# Out:
#                    random_seed   tst acc  depth       rob
# dataset
# risk_adult                 4.5  0.829769  414.2  0.500100
# risk_bank                  4.5  0.897300   30.7  0.500100
# risk_bank_2                4.5  0.912624   30.0  0.115382
# risk_breastcancer          4.5  0.940265   15.2  0.233600
# risk_careval               4.5  0.971979   59.3  0.500100
# risk_compasbin             4.5  0.666754   67.8  0.500100
# risk_diabetes              4.5  0.736614   31.2  0.075660
# risk_ficobin               4.5  0.714195   30.6  0.500100
# risk_heart                 4.5  0.762222   20.3  0.233167
# risk_ionosphere            4.5  0.889655   11.3  0.149362
# risk_mammo                 4.5  0.793711   27.4  0.467267
# risk_mushroom              4.5  1.000000   10.8  0.500100
# risk_spambase              4.5  0.918104  153.9  0.003959

# %%
xgb_df = display_results(XgboostRobDTInterpretRobExperiments, '../results/xgboostrobdt_interpret_rob/', ['tst acc', 'adv tst dist', 'er dist', 'best_clf'])

# %%
columns = ['dataset', 'random_seed', 'tst acc', 'depth', 'rob']
column_names = ['dataset', 'random_seed', 'tst acc', 'depth', 'rob']
#df = display_results(RobDTInterpretRobExperiments3, '../results/robdt_interpret_rob_3/', ['tst acc', 'adv tst dist', 'depth', 'leaves'])
df = proc_xgb_result(xgb_df, rsep=0.05)
robdt_df = df[columns]
robdt_df.columns = column_names
robdt_df.groupby("dataset").mean()
# Out:
#                    random_seed   tst acc  depth       rob
# dataset
# risk_adult                 4.5  0.829099  287.9  0.496500
# risk_bank                  4.5  0.897322   26.8  0.500000
# risk_bank_2                4.5  0.904819   30.7  0.175062
# risk_breastcancer          4.5  0.943363    7.4  0.285000
# risk_careval               4.5  0.957268   28.2  0.500000
# risk_compasbin             4.5  0.668509   33.7  0.498000
# risk_diabetes              4.5  0.733465   27.9  0.080972
# risk_ficobin               4.5  0.711935   59.6  0.499000
# risk_heart                 4.5  0.793333   13.6  0.306167
# risk_ionosphere            4.5  0.921552    8.6  0.249877
# risk_mammo                 4.5  0.794025   12.4  0.497167
# risk_mushroom              4.5  0.998806    9.1  0.500000
# risk_spambase              4.5  0.874062   72.3  0.044139

# %%
ddff = df_bbm.merge(rudin_df, on=['dataset', 'random_seed'], suffixes=("_bbm", ""))
ddff = ddff.merge(dt_df, on=['dataset', 'random_seed'], suffixes=("", "_DT"))
ddff = ddff.merge(robdt_df, on=['dataset', 'random_seed'], suffixes=("", "_robDT"))
ddff.groupby("dataset").mean()
# Out:
#                    random_seed  tst acc_bbm  depth_bbm   rob_bbm   tst acc  \
# dataset
# risk_adult                 4.5     0.812274        6.0  0.500014  0.824195
# risk_bank                  4.5     0.896300        8.0  0.500003  0.896447
# risk_bank_2                4.5     0.896822        4.5  0.498001  0.899676
# risk_breastcancer          4.5     0.957522       11.0  0.274703  0.957080
# risk_careval               4.5     0.769702        8.7  0.495063  0.906305
# risk_compasbin             4.5     0.662456        7.6  0.331743  0.651140
# risk_diabetes              4.5     0.650000        2.1  0.145283  0.762598
# risk_ficobin               4.5     0.721118       11.8  0.500044  0.713094
# risk_heart                 4.5     0.822222        9.5  0.323431  0.816667
# risk_ionosphere            4.5     0.856897        6.8  0.275112  0.878448
# risk_mammo                 4.5     0.771384        1.9  0.495042  0.791509
# risk_mushroom              4.5     0.966803        9.9  0.500047  0.999925
# risk_spambase              4.5     0.788545        5.6  0.047710  0.881040
#
#                    depth       rob  tst acc_DT  depth_DT    rob_DT  \
# dataset
# risk_adult          14.9  0.123850    0.829769     414.2  0.500100
# risk_bank            8.9  0.198242    0.897300      30.7  0.500100
# risk_bank_2         13.8  0.104087    0.912624      30.0  0.115382
# risk_breastcancer    6.0  0.277423    0.940265      15.2  0.233600
# risk_careval        10.1  0.190866    0.971979      59.3  0.500100
# risk_compasbin       5.4  0.147302    0.666754      67.8  0.500100
# risk_diabetes        6.0  0.092907    0.736614      31.2  0.075660
# risk_ficobin         6.4  0.221749    0.714195      30.6  0.500100
# risk_heart          11.9  0.137193    0.762222      20.3  0.233167
# risk_ionosphere     17.9  0.070969    0.889655      11.3  0.149362
# risk_mammo           7.2  0.213982    0.793711      27.4  0.467267
# risk_mushroom       23.8  0.095776    1.000000      10.8  0.500100
# risk_spambase       29.5  0.016140    0.918104     153.9  0.003959
#
#                    tst acc_robDT  depth_robDT  rob_robDT
# dataset
# risk_adult              0.829099        287.9   0.496500
# risk_bank               0.897322         26.8   0.500000
# risk_bank_2             0.904819         30.7   0.175062
# risk_breastcancer       0.943363          7.4   0.285000
# risk_careval            0.957268         28.2   0.500000
# risk_compasbin          0.668509         33.7   0.498000
# risk_diabetes           0.733465         27.9   0.080972
# risk_ficobin            0.711935         59.6   0.499000
# risk_heart              0.793333         13.6   0.306167
# risk_ionosphere         0.921552          8.6   0.249877
# risk_mammo              0.794025         12.4   0.497167
# risk_mushroom           0.998806          9.1   0.500000
# risk_spambase           0.874062         72.3   0.044139

# %%
data = {}
#columns = ['depth_DT', 'depth_robDT', 'depth', 'depth_bbm',
#           'tst acc_DT', 'tst acc_robDT', 'tst acc', 'tst acc_bbm',
#           'rob_DT', 'rob_robDT', 'rob', 'rob_bbm'] 
columns = ['depth_DT', 'depth_robDT', 'depth', 'depth_bbm',
           'tst acc_DT', 'tst acc_robDT', 'tst acc', 'tst acc_bbm',
           'rob_DT', 'rob_robDT', 'rob', 'rob_bbm'] 
for name, group in ddff.groupby("dataset"):
    name = name.replace("risk_", "")
    data[name] = []
    mean = group[columns].mean()
    sem = group[columns].sem()
    for m, s in zip(mean, sem):
        data[name].append(f"${m:.2f} \pm {s:.2f}$".replace(" 0.", " ."))
ddff2 = pd.DataFrame.from_dict(data, orient='index')
#ddff2.columns = ["depth", "depth", "\# weak learners", "\# non-zero weights",
#                "test acc. (DT)", "test acc. (RobDT)", "test acc. (BBM)", "test acc. (Rudin's)",
#                "ER (DT)", "ER (RobDT)", "ER (BBM)", "ER (Rudin's)"]
ddff2.columns = ["DT", "RobDT", "Rudin's", "BBM",
                 "DT2", "RobDT2", "Rudin's2", "BBM2",
                 "DT3", "RobDT3", "Rudin's3", "BBM3",]
print(ddff2.to_latex(escape=False, column_format="lcccccccccccc"))
# Out:
# \begin{tabular}{lcccccccccccc}
# \toprule
# {} &                 DT &               RobDT &           Rudin's &              BBM &             DT2 &          RobDT2 &        Rudin's2 &            BBM2 &             DT3 &          RobDT3 &        Rudin's3 &            BBM3 \\
# \midrule
# adult        &  $414.20 \pm 5.66$ &  $287.90 \pm 35.66$ &  $14.90 \pm 1.46$ &   $6.00 \pm .60$ &  $0.83 \pm .00$ &  $0.83 \pm .00$ &  $0.82 \pm .00$ &  $0.81 \pm .00$ &  $0.50 \pm .00$ &  $0.50 \pm .00$ &  $0.12 \pm .02$ &  $0.50 \pm .00$ \\
# bank         &    $30.70 \pm .15$ &     $26.80 \pm .20$ &    $8.90 \pm .66$ &  $8.00 \pm 1.41$ &  $0.90 \pm .00$ &  $0.90 \pm .00$ &  $0.90 \pm .00$ &  $0.90 \pm .00$ &  $0.50 \pm .00$ &  $0.50 \pm .00$ &  $0.20 \pm .03$ &  $0.50 \pm .00$ \\
# bank_2       &    $30.00 \pm .30$ &     $30.70 \pm .15$ &  $13.80 \pm 1.54$ &  $4.50 \pm 1.34$ &  $0.91 \pm .00$ &  $0.90 \pm .00$ &  $0.90 \pm .00$ &  $0.90 \pm .00$ &  $0.12 \pm .01$ &  $0.18 \pm .02$ &  $0.10 \pm .01$ &  $0.50 \pm .00$ \\
# breastcancer &   $15.20 \pm 1.25$ &      $7.40 \pm .60$ &    $6.00 \pm .00$ &  $11.00 \pm .89$ &  $0.94 \pm .00$ &  $0.94 \pm .01$ &  $0.96 \pm .00$ &  $0.96 \pm .01$ &  $0.23 \pm .01$ &  $0.29 \pm .01$ &  $0.28 \pm .00$ &  $0.27 \pm .01$ \\
# careval      &   $59.30 \pm 2.22$ &     $28.20 \pm .65$ &   $10.10 \pm .97$ &   $8.70 \pm .47$ &  $0.97 \pm .00$ &  $0.96 \pm .00$ &  $0.91 \pm .01$ &  $0.77 \pm .00$ &  $0.50 \pm .00$ &  $0.50 \pm .00$ &  $0.19 \pm .02$ &  $0.50 \pm .00$ \\
# compasbin    &  $67.80 \pm 13.01$ &    $33.70 \pm 3.05$ &    $5.40 \pm .22$ &   $7.60 \pm .16$ &  $0.67 \pm .00$ &  $0.67 \pm .00$ &  $0.65 \pm .00$ &  $0.66 \pm .00$ &  $0.50 \pm .00$ &  $0.50 \pm .00$ &  $0.15 \pm .01$ &  $0.33 \pm .01$ \\
# diabetes     &   $31.20 \pm 6.96$ &    $27.90 \pm 2.95$ &    $6.00 \pm .00$ &   $2.10 \pm .53$ &  $0.74 \pm .01$ &  $0.73 \pm .01$ &  $0.76 \pm .01$ &  $0.65 \pm .01$ &  $0.08 \pm .01$ &  $0.08 \pm .00$ &  $0.09 \pm .00$ &  $0.15 \pm .05$ \\
# ficobin      &    $30.60 \pm .22$ &   $59.60 \pm 29.82$ &    $6.40 \pm .16$ &  $11.80 \pm .65$ &  $0.71 \pm .00$ &  $0.71 \pm .00$ &  $0.71 \pm .00$ &  $0.72 \pm .00$ &  $0.50 \pm .00$ &  $0.50 \pm .00$ &  $0.22 \pm .01$ &  $0.50 \pm .00$ \\
# heart        &   $20.30 \pm 1.60$ &     $13.60 \pm .88$ &  $11.90 \pm 1.46$ &   $9.50 \pm .82$ &  $0.76 \pm .01$ &  $0.79 \pm .01$ &  $0.82 \pm .01$ &  $0.82 \pm .01$ &  $0.23 \pm .02$ &  $0.31 \pm .02$ &  $0.14 \pm .01$ &  $0.32 \pm .02$ \\
# ionosphere   &    $11.30 \pm .98$ &      $8.60 \pm .76$ &  $17.90 \pm 3.14$ &  $6.80 \pm 1.96$ &  $0.89 \pm .01$ &  $0.92 \pm .01$ &  $0.88 \pm .01$ &  $0.86 \pm .01$ &  $0.15 \pm .01$ &  $0.25 \pm .01$ &  $0.07 \pm .01$ &  $0.28 \pm .01$ \\
# mammo        &   $27.40 \pm 5.09$ &     $12.40 \pm .65$ &    $7.20 \pm .65$ &   $1.90 \pm .60$ &  $0.79 \pm .00$ &  $0.79 \pm .00$ &  $0.79 \pm .00$ &  $0.77 \pm .00$ &  $0.47 \pm .01$ &  $0.50 \pm .00$ &  $0.21 \pm .02$ &  $0.50 \pm .00$ \\
# mushroom     &    $10.80 \pm .25$ &      $9.10 \pm .10$ &  $23.80 \pm 1.50$ &   $9.90 \pm .89$ &  $1.00 \pm .00$ &  $1.00 \pm .00$ &  $1.00 \pm .00$ &  $0.97 \pm .00$ &  $0.50 \pm .00$ &  $0.50 \pm .00$ &  $0.10 \pm .01$ &  $0.50 \pm .00$ \\
# spambase     &  $153.90 \pm 8.51$ &    $72.30 \pm 2.89$ &   $29.50 \pm .76$ &   $5.60 \pm .48$ &  $0.92 \pm .00$ &  $0.87 \pm .00$ &  $0.88 \pm .00$ &  $0.79 \pm .01$ &  $0.00 \pm .00$ &  $0.04 \pm .00$ &  $0.02 \pm .00$ &  $0.05 \pm .00$ \\
# \bottomrule
# \end{tabular}

# %%
def bold_best(df, max_is_best=True):
    for i, d in df.iterrows():
        ents = []
        for ent in d:
            ents.append(float(ent[1:-1].split(" \\pm ")[0]))
        if max_is_best:
            best_id = np.argmax(ents)
        else:
            best_id = np.argmin(ents)
        best_number = float(d[best_id][1:-1].split(" \\pm ")[0])
        for i in range(len(d)):
            if float(d[i][1:-1].split(" \\pm ")[0]) == best_number:
                d[i] =  f"$\\mathbf{{{d[i][1:-1]}}}$"
    return df

d1 = bold_best(ddff2[["DT", "RobDT", "Rudin's", "BBM"]], max_is_best=False)
d2 = bold_best(ddff2[["DT2", "RobDT2", "Rudin's2", "BBM2"]], max_is_best=True)
d3 = bold_best(ddff2[["DT3", "RobDT3", "Rudin's3", "BBM3"]], max_is_best=True)
ddff3 = pd.concat((d1, d2, d3), axis=1)
print(ddff3.to_latex(escape=False, column_format="lcccccccccccc"))
ddff3
# Out:
# \begin{tabular}{lcccccccccccc}
# \toprule
# {} &                 DT &                    RobDT &                  Rudin's &                       BBM &                      DT2 &                   RobDT2 &                 Rudin's2 &                     BBM2 &                      DT3 &                   RobDT3 &        Rudin's3 &                     BBM3 \\
# \midrule
# adult        &  $414.20 \pm 5.66$ &       $287.90 \pm 35.66$ &         $14.90 \pm 1.46$ &   $\mathbf{6.00 \pm .60}$ &  $\mathbf{0.83 \pm .00}$ &  $\mathbf{0.83 \pm .00}$ &           $0.82 \pm .00$ &           $0.81 \pm .00$ &  $\mathbf{0.50 \pm .00}$ &  $\mathbf{0.50 \pm .00}$ &  $0.12 \pm .02$ &  $\mathbf{0.50 \pm .00}$ \\
# bank         &    $30.70 \pm .15$ &          $26.80 \pm .20$ &           $8.90 \pm .66$ &  $\mathbf{8.00 \pm 1.41}$ &  $\mathbf{0.90 \pm .00}$ &  $\mathbf{0.90 \pm .00}$ &  $\mathbf{0.90 \pm .00}$ &  $\mathbf{0.90 \pm .00}$ &  $\mathbf{0.50 \pm .00}$ &  $\mathbf{0.50 \pm .00}$ &  $0.20 \pm .03$ &  $\mathbf{0.50 \pm .00}$ \\
# bank_2       &    $30.00 \pm .30$ &          $30.70 \pm .15$ &         $13.80 \pm 1.54$ &  $\mathbf{4.50 \pm 1.34}$ &  $\mathbf{0.91 \pm .00}$ &           $0.90 \pm .00$ &           $0.90 \pm .00$ &           $0.90 \pm .00$ &           $0.12 \pm .01$ &           $0.18 \pm .02$ &  $0.10 \pm .01$ &  $\mathbf{0.50 \pm .00}$ \\
# breastcancer &   $15.20 \pm 1.25$ &           $7.40 \pm .60$ &  $\mathbf{6.00 \pm .00}$ &           $11.00 \pm .89$ &           $0.94 \pm .00$ &           $0.94 \pm .01$ &  $\mathbf{0.96 \pm .00}$ &  $\mathbf{0.96 \pm .01}$ &           $0.23 \pm .01$ &  $\mathbf{0.29 \pm .01}$ &  $0.28 \pm .00$ &           $0.27 \pm .01$ \\
# careval      &   $59.30 \pm 2.22$ &          $28.20 \pm .65$ &          $10.10 \pm .97$ &   $\mathbf{8.70 \pm .47}$ &  $\mathbf{0.97 \pm .00}$ &           $0.96 \pm .00$ &           $0.91 \pm .01$ &           $0.77 \pm .00$ &  $\mathbf{0.50 \pm .00}$ &  $\mathbf{0.50 \pm .00}$ &  $0.19 \pm .02$ &  $\mathbf{0.50 \pm .00}$ \\
# compasbin    &  $67.80 \pm 13.01$ &         $33.70 \pm 3.05$ &  $\mathbf{5.40 \pm .22}$ &            $7.60 \pm .16$ &  $\mathbf{0.67 \pm .00}$ &  $\mathbf{0.67 \pm .00}$ &           $0.65 \pm .00$ &           $0.66 \pm .00$ &  $\mathbf{0.50 \pm .00}$ &  $\mathbf{0.50 \pm .00}$ &  $0.15 \pm .01$ &           $0.33 \pm .01$ \\
# diabetes     &   $31.20 \pm 6.96$ &         $27.90 \pm 2.95$ &           $6.00 \pm .00$ &   $\mathbf{2.10 \pm .53}$ &           $0.74 \pm .01$ &           $0.73 \pm .01$ &  $\mathbf{0.76 \pm .01}$ &           $0.65 \pm .01$ &           $0.08 \pm .01$ &           $0.08 \pm .00$ &  $0.09 \pm .00$ &  $\mathbf{0.15 \pm .05}$ \\
# ficobin      &    $30.60 \pm .22$ &        $59.60 \pm 29.82$ &  $\mathbf{6.40 \pm .16}$ &           $11.80 \pm .65$ &           $0.71 \pm .00$ &           $0.71 \pm .00$ &           $0.71 \pm .00$ &  $\mathbf{0.72 \pm .00}$ &  $\mathbf{0.50 \pm .00}$ &  $\mathbf{0.50 \pm .00}$ &  $0.22 \pm .01$ &  $\mathbf{0.50 \pm .00}$ \\
# heart        &   $20.30 \pm 1.60$ &          $13.60 \pm .88$ &         $11.90 \pm 1.46$ &   $\mathbf{9.50 \pm .82}$ &           $0.76 \pm .01$ &           $0.79 \pm .01$ &  $\mathbf{0.82 \pm .01}$ &  $\mathbf{0.82 \pm .01}$ &           $0.23 \pm .02$ &           $0.31 \pm .02$ &  $0.14 \pm .01$ &  $\mathbf{0.32 \pm .02}$ \\
# ionosphere   &    $11.30 \pm .98$ &           $8.60 \pm .76$ &         $17.90 \pm 3.14$ &  $\mathbf{6.80 \pm 1.96}$ &           $0.89 \pm .01$ &  $\mathbf{0.92 \pm .01}$ &           $0.88 \pm .01$ &           $0.86 \pm .01$ &           $0.15 \pm .01$ &           $0.25 \pm .01$ &  $0.07 \pm .01$ &  $\mathbf{0.28 \pm .01}$ \\
# mammo        &   $27.40 \pm 5.09$ &          $12.40 \pm .65$ &           $7.20 \pm .65$ &   $\mathbf{1.90 \pm .60}$ &  $\mathbf{0.79 \pm .00}$ &  $\mathbf{0.79 \pm .00}$ &  $\mathbf{0.79 \pm .00}$ &           $0.77 \pm .00$ &           $0.47 \pm .01$ &  $\mathbf{0.50 \pm .00}$ &  $0.21 \pm .02$ &  $\mathbf{0.50 \pm .00}$ \\
# mushroom     &    $10.80 \pm .25$ &  $\mathbf{9.10 \pm .10}$ &         $23.80 \pm 1.50$ &            $9.90 \pm .89$ &  $\mathbf{1.00 \pm .00}$ &  $\mathbf{1.00 \pm .00}$ &  $\mathbf{1.00 \pm .00}$ &           $0.97 \pm .00$ &  $\mathbf{0.50 \pm .00}$ &  $\mathbf{0.50 \pm .00}$ &  $0.10 \pm .01$ &  $\mathbf{0.50 \pm .00}$ \\
# spambase     &  $153.90 \pm 8.51$ &         $72.30 \pm 2.89$ &          $29.50 \pm .76$ &   $\mathbf{5.60 \pm .48}$ &  $\mathbf{0.92 \pm .00}$ &           $0.87 \pm .00$ &           $0.88 \pm .00$ &           $0.79 \pm .01$ &           $0.00 \pm .00$ &           $0.04 \pm .00$ &  $0.02 \pm .00$ &  $\mathbf{0.05 \pm .00}$ \\
# \bottomrule
# \end{tabular}
#                              DT                    RobDT  \
# adult         $414.20 \pm 5.66$       $287.90 \pm 35.66$
# bank            $30.70 \pm .15$          $26.80 \pm .20$
# bank_2          $30.00 \pm .30$          $30.70 \pm .15$
# breastcancer   $15.20 \pm 1.25$           $7.40 \pm .60$
# careval        $59.30 \pm 2.22$          $28.20 \pm .65$
# compasbin     $67.80 \pm 13.01$         $33.70 \pm 3.05$
# diabetes       $31.20 \pm 6.96$         $27.90 \pm 2.95$
# ficobin         $30.60 \pm .22$        $59.60 \pm 29.82$
# heart          $20.30 \pm 1.60$          $13.60 \pm .88$
# ionosphere      $11.30 \pm .98$           $8.60 \pm .76$
# mammo          $27.40 \pm 5.09$          $12.40 \pm .65$
# mushroom        $10.80 \pm .25$  $\mathbf{9.10 \pm .10}$
# spambase      $153.90 \pm 8.51$         $72.30 \pm 2.89$
#
#                               Rudin's                       BBM  \
# adult                $14.90 \pm 1.46$   $\mathbf{6.00 \pm .60}$
# bank                   $8.90 \pm .66$  $\mathbf{8.00 \pm 1.41}$
# bank_2               $13.80 \pm 1.54$  $\mathbf{4.50 \pm 1.34}$
# breastcancer  $\mathbf{6.00 \pm .00}$           $11.00 \pm .89$
# careval               $10.10 \pm .97$   $\mathbf{8.70 \pm .47}$
# compasbin     $\mathbf{5.40 \pm .22}$            $7.60 \pm .16$
# diabetes               $6.00 \pm .00$   $\mathbf{2.10 \pm .53}$
# ficobin       $\mathbf{6.40 \pm .16}$           $11.80 \pm .65$
# heart                $11.90 \pm 1.46$   $\mathbf{9.50 \pm .82}$
# ionosphere           $17.90 \pm 3.14$  $\mathbf{6.80 \pm 1.96}$
# mammo                  $7.20 \pm .65$   $\mathbf{1.90 \pm .60}$
# mushroom             $23.80 \pm 1.50$            $9.90 \pm .89$
# spambase              $29.50 \pm .76$   $\mathbf{5.60 \pm .48}$
#
#                                   DT2                   RobDT2  \
# adult         $\mathbf{0.83 \pm .00}$  $\mathbf{0.83 \pm .00}$
# bank          $\mathbf{0.90 \pm .00}$  $\mathbf{0.90 \pm .00}$
# bank_2        $\mathbf{0.91 \pm .00}$           $0.90 \pm .00$
# breastcancer           $0.94 \pm .00$           $0.94 \pm .01$
# careval       $\mathbf{0.97 \pm .00}$           $0.96 \pm .00$
# compasbin     $\mathbf{0.67 \pm .00}$  $\mathbf{0.67 \pm .00}$
# diabetes               $0.74 \pm .01$           $0.73 \pm .01$
# ficobin                $0.71 \pm .00$           $0.71 \pm .00$
# heart                  $0.76 \pm .01$           $0.79 \pm .01$
# ionosphere             $0.89 \pm .01$  $\mathbf{0.92 \pm .01}$
# mammo         $\mathbf{0.79 \pm .00}$  $\mathbf{0.79 \pm .00}$
# mushroom      $\mathbf{1.00 \pm .00}$  $\mathbf{1.00 \pm .00}$
# spambase      $\mathbf{0.92 \pm .00}$           $0.87 \pm .00$
#
#                              Rudin's2                     BBM2  \
# adult                  $0.82 \pm .00$           $0.81 \pm .00$
# bank          $\mathbf{0.90 \pm .00}$  $\mathbf{0.90 \pm .00}$
# bank_2                 $0.90 \pm .00$           $0.90 \pm .00$
# breastcancer  $\mathbf{0.96 \pm .00}$  $\mathbf{0.96 \pm .01}$
# careval                $0.91 \pm .01$           $0.77 \pm .00$
# compasbin              $0.65 \pm .00$           $0.66 \pm .00$
# diabetes      $\mathbf{0.76 \pm .01}$           $0.65 \pm .01$
# ficobin                $0.71 \pm .00$  $\mathbf{0.72 \pm .00}$
# heart         $\mathbf{0.82 \pm .01}$  $\mathbf{0.82 \pm .01}$
# ionosphere             $0.88 \pm .01$           $0.86 \pm .01$
# mammo         $\mathbf{0.79 \pm .00}$           $0.77 \pm .00$
# mushroom      $\mathbf{1.00 \pm .00}$           $0.97 \pm .00$
# spambase               $0.88 \pm .00$           $0.79 \pm .01$
#
#                                   DT3                   RobDT3  \
# adult         $\mathbf{0.50 \pm .00}$  $\mathbf{0.50 \pm .00}$
# bank          $\mathbf{0.50 \pm .00}$  $\mathbf{0.50 \pm .00}$
# bank_2                 $0.12 \pm .01$           $0.18 \pm .02$
# breastcancer           $0.23 \pm .01$  $\mathbf{0.29 \pm .01}$
# careval       $\mathbf{0.50 \pm .00}$  $\mathbf{0.50 \pm .00}$
# compasbin     $\mathbf{0.50 \pm .00}$  $\mathbf{0.50 \pm .00}$
# diabetes               $0.08 \pm .01$           $0.08 \pm .00$
# ficobin       $\mathbf{0.50 \pm .00}$  $\mathbf{0.50 \pm .00}$
# heart                  $0.23 \pm .02$           $0.31 \pm .02$
# ionosphere             $0.15 \pm .01$           $0.25 \pm .01$
# mammo                  $0.47 \pm .01$  $\mathbf{0.50 \pm .00}$
# mushroom      $\mathbf{0.50 \pm .00}$  $\mathbf{0.50 \pm .00}$
# spambase               $0.00 \pm .00$           $0.04 \pm .00$
#
#                     Rudin's3                     BBM3
# adult         $0.12 \pm .02$  $\mathbf{0.50 \pm .00}$
# bank          $0.20 \pm .03$  $\mathbf{0.50 \pm .00}$
# bank_2        $0.10 \pm .01$  $\mathbf{0.50 \pm .00}$
# breastcancer  $0.28 \pm .00$           $0.27 \pm .01$
# careval       $0.19 \pm .02$  $\mathbf{0.50 \pm .00}$
# compasbin     $0.15 \pm .01$           $0.33 \pm .01$
# diabetes      $0.09 \pm .00$  $\mathbf{0.15 \pm .05}$
# ficobin       $0.22 \pm .01$  $\mathbf{0.50 \pm .00}$
# heart         $0.14 \pm .01$  $\mathbf{0.32 \pm .02}$
# ionosphere    $0.07 \pm .01$  $\mathbf{0.28 \pm .01}$
# mammo         $0.21 \pm .02$  $\mathbf{0.50 \pm .00}$
# mushroom      $0.10 \pm .01$  $\mathbf{0.50 \pm .00}$
# spambase      $0.02 \pm .00$  $\mathbf{0.05 \pm .00}$

# %%
def bold_best(df, max_is_best=True):
    for i, d in df.iterrows():
        ents = []
        for ent in d:
            ents.append(float(ent[1:-1].split(" \\pm ")[0]))
        if max_is_best:
            best_id = np.argmax(ents)
        else:
            best_id = np.argmin(ents)
        best_number = float(d[best_id][1:-1].split(" \\pm ")[0])
        for i in range(len(d)):
            temp = d[i][1:-1].split(' \\pm ')[0]
            if float(d[i][1:-1].split(" \\pm ")[0]) == best_number:
                d[i] = f"$\\mathbf{{{temp}}}$"
            else:
                d[i] = f"${temp}$"
    return df

d1 = bold_best(ddff2[["DT", "RobDT", "Rudin's", "BBM"]], max_is_best=False)
d2 = bold_best(ddff2[["DT2", "RobDT2", "Rudin's2", "BBM2"]], max_is_best=True)
d3 = bold_best(ddff2[["DT3", "RobDT3", "Rudin's3", "BBM3"]], max_is_best=True)
ddff3 = pd.concat((d1, d2, d3), axis=1)
print(ddff3.to_latex(escape=False, column_format="lcccccccccccc"))
ddff3
# Out:
# \begin{tabular}{lcccccccccccc}
# \toprule
# {} &        DT &            RobDT &          Rudin's &              BBM &              DT2 &           RobDT2 &         Rudin's2 &             BBM2 &              DT3 &           RobDT3 & Rudin's3 &             BBM3 \\
# \midrule
# adult        &  $414.20$ &         $287.90$ &          $14.90$ &  $\mathbf{6.00}$ &  $\mathbf{0.83}$ &  $\mathbf{0.83}$ &           $0.82$ &           $0.81$ &  $\mathbf{0.50}$ &  $\mathbf{0.50}$ &   $0.12$ &  $\mathbf{0.50}$ \\
# bank         &   $30.70$ &          $26.80$ &           $8.90$ &  $\mathbf{8.00}$ &  $\mathbf{0.90}$ &  $\mathbf{0.90}$ &  $\mathbf{0.90}$ &  $\mathbf{0.90}$ &  $\mathbf{0.50}$ &  $\mathbf{0.50}$ &   $0.20$ &  $\mathbf{0.50}$ \\
# bank_2       &   $30.00$ &          $30.70$ &          $13.80$ &  $\mathbf{4.50}$ &  $\mathbf{0.91}$ &           $0.90$ &           $0.90$ &           $0.90$ &           $0.12$ &           $0.18$ &   $0.10$ &  $\mathbf{0.50}$ \\
# breastcancer &   $15.20$ &           $7.40$ &  $\mathbf{6.00}$ &          $11.00$ &           $0.94$ &           $0.94$ &  $\mathbf{0.96}$ &  $\mathbf{0.96}$ &           $0.23$ &  $\mathbf{0.29}$ &   $0.28$ &           $0.27$ \\
# careval      &   $59.30$ &          $28.20$ &          $10.10$ &  $\mathbf{8.70}$ &  $\mathbf{0.97}$ &           $0.96$ &           $0.91$ &           $0.77$ &  $\mathbf{0.50}$ &  $\mathbf{0.50}$ &   $0.19$ &  $\mathbf{0.50}$ \\
# compasbin    &   $67.80$ &          $33.70$ &  $\mathbf{5.40}$ &           $7.60$ &  $\mathbf{0.67}$ &  $\mathbf{0.67}$ &           $0.65$ &           $0.66$ &  $\mathbf{0.50}$ &  $\mathbf{0.50}$ &   $0.15$ &           $0.33$ \\
# diabetes     &   $31.20$ &          $27.90$ &           $6.00$ &  $\mathbf{2.10}$ &           $0.74$ &           $0.73$ &  $\mathbf{0.76}$ &           $0.65$ &           $0.08$ &           $0.08$ &   $0.09$ &  $\mathbf{0.15}$ \\
# ficobin      &   $30.60$ &          $59.60$ &  $\mathbf{6.40}$ &          $11.80$ &           $0.71$ &           $0.71$ &           $0.71$ &  $\mathbf{0.72}$ &  $\mathbf{0.50}$ &  $\mathbf{0.50}$ &   $0.22$ &  $\mathbf{0.50}$ \\
# heart        &   $20.30$ &          $13.60$ &          $11.90$ &  $\mathbf{9.50}$ &           $0.76$ &           $0.79$ &  $\mathbf{0.82}$ &  $\mathbf{0.82}$ &           $0.23$ &           $0.31$ &   $0.14$ &  $\mathbf{0.32}$ \\
# ionosphere   &   $11.30$ &           $8.60$ &          $17.90$ &  $\mathbf{6.80}$ &           $0.89$ &  $\mathbf{0.92}$ &           $0.88$ &           $0.86$ &           $0.15$ &           $0.25$ &   $0.07$ &  $\mathbf{0.28}$ \\
# mammo        &   $27.40$ &          $12.40$ &           $7.20$ &  $\mathbf{1.90}$ &  $\mathbf{0.79}$ &  $\mathbf{0.79}$ &  $\mathbf{0.79}$ &           $0.77$ &           $0.47$ &  $\mathbf{0.50}$ &   $0.21$ &  $\mathbf{0.50}$ \\
# mushroom     &   $10.80$ &  $\mathbf{9.10}$ &          $23.80$ &           $9.90$ &  $\mathbf{1.00}$ &  $\mathbf{1.00}$ &  $\mathbf{1.00}$ &           $0.97$ &  $\mathbf{0.50}$ &  $\mathbf{0.50}$ &   $0.10$ &  $\mathbf{0.50}$ \\
# spambase     &  $153.90$ &          $72.30$ &          $29.50$ &  $\mathbf{5.60}$ &  $\mathbf{0.92}$ &           $0.87$ &           $0.88$ &           $0.79$ &           $0.00$ &           $0.04$ &   $0.02$ &  $\mathbf{0.05}$ \\
# \bottomrule
# \end{tabular}
#                     DT            RobDT          Rudin's              BBM  \
# adult         $414.20$         $287.90$          $14.90$  $\mathbf{6.00}$
# bank           $30.70$          $26.80$           $8.90$  $\mathbf{8.00}$
# bank_2         $30.00$          $30.70$          $13.80$  $\mathbf{4.50}$
# breastcancer   $15.20$           $7.40$  $\mathbf{6.00}$          $11.00$
# careval        $59.30$          $28.20$          $10.10$  $\mathbf{8.70}$
# compasbin      $67.80$          $33.70$  $\mathbf{5.40}$           $7.60$
# diabetes       $31.20$          $27.90$           $6.00$  $\mathbf{2.10}$
# ficobin        $30.60$          $59.60$  $\mathbf{6.40}$          $11.80$
# heart          $20.30$          $13.60$          $11.90$  $\mathbf{9.50}$
# ionosphere     $11.30$           $8.60$          $17.90$  $\mathbf{6.80}$
# mammo          $27.40$          $12.40$           $7.20$  $\mathbf{1.90}$
# mushroom       $10.80$  $\mathbf{9.10}$          $23.80$           $9.90$
# spambase      $153.90$          $72.30$          $29.50$  $\mathbf{5.60}$
#
#                           DT2           RobDT2         Rudin's2  \
# adult         $\mathbf{0.83}$  $\mathbf{0.83}$           $0.82$
# bank          $\mathbf{0.90}$  $\mathbf{0.90}$  $\mathbf{0.90}$
# bank_2        $\mathbf{0.91}$           $0.90$           $0.90$
# breastcancer           $0.94$           $0.94$  $\mathbf{0.96}$
# careval       $\mathbf{0.97}$           $0.96$           $0.91$
# compasbin     $\mathbf{0.67}$  $\mathbf{0.67}$           $0.65$
# diabetes               $0.74$           $0.73$  $\mathbf{0.76}$
# ficobin                $0.71$           $0.71$           $0.71$
# heart                  $0.76$           $0.79$  $\mathbf{0.82}$
# ionosphere             $0.89$  $\mathbf{0.92}$           $0.88$
# mammo         $\mathbf{0.79}$  $\mathbf{0.79}$  $\mathbf{0.79}$
# mushroom      $\mathbf{1.00}$  $\mathbf{1.00}$  $\mathbf{1.00}$
# spambase      $\mathbf{0.92}$           $0.87$           $0.88$
#
#                          BBM2              DT3           RobDT3 Rudin's3  \
# adult                  $0.81$  $\mathbf{0.50}$  $\mathbf{0.50}$   $0.12$
# bank          $\mathbf{0.90}$  $\mathbf{0.50}$  $\mathbf{0.50}$   $0.20$
# bank_2                 $0.90$           $0.12$           $0.18$   $0.10$
# breastcancer  $\mathbf{0.96}$           $0.23$  $\mathbf{0.29}$   $0.28$
# careval                $0.77$  $\mathbf{0.50}$  $\mathbf{0.50}$   $0.19$
# compasbin              $0.66$  $\mathbf{0.50}$  $\mathbf{0.50}$   $0.15$
# diabetes               $0.65$           $0.08$           $0.08$   $0.09$
# ficobin       $\mathbf{0.72}$  $\mathbf{0.50}$  $\mathbf{0.50}$   $0.22$
# heart         $\mathbf{0.82}$           $0.23$           $0.31$   $0.14$
# ionosphere             $0.86$           $0.15$           $0.25$   $0.07$
# mammo                  $0.77$           $0.47$  $\mathbf{0.50}$   $0.21$
# mushroom               $0.97$  $\mathbf{0.50}$  $\mathbf{0.50}$   $0.10$
# spambase               $0.79$           $0.00$           $0.04$   $0.02$
#
#                          BBM3
# adult         $\mathbf{0.50}$
# bank          $\mathbf{0.50}$
# bank_2        $\mathbf{0.50}$
# breastcancer           $0.27$
# careval       $\mathbf{0.50}$
# compasbin              $0.33$
# diabetes      $\mathbf{0.15}$
# ficobin       $\mathbf{0.50}$
# heart         $\mathbf{0.32}$
# ionosphere    $\mathbf{0.28}$
# mammo         $\mathbf{0.50}$
# mushroom      $\mathbf{0.50}$
# spambase      $\mathbf{0.05}$

# %%
res = joblib.load("../results/lin_sep_bbm_rob_3/risk_compasbin-rminmax-4.pkl")
res['bbm_results']['er dist']
# Out:
# array([0.50000001, 0.50000001, 0.10010001, 0.50000001, 0.50000001,
#        0.50010001, 0.10010001, 0.50000001, 0.10010001, 0.50000001,
#        0.10010001, 0.10010001, 0.10010001, 0.50010001, 0.50010001,
#        0.10010001, 0.50000001, 0.50000001, 0.10010001, 0.50000001,
#        0.50000001, 0.50000001, 0.10010001, 0.10010001, 0.50010001,
#        0.50000001, 0.10010001, 0.10010001, 0.50000001, 0.10010001,
#        0.50010001, 0.50000001, 0.50000001, 0.10010001, 0.10010001,
#        0.50000001, 0.10010001, 0.10010001, 0.50000001, 0.50000001,
#        0.50000001, 0.50000001, 0.50000001, 0.10010001, 0.50000001,
#        0.50000001, 0.50000001, 0.50000001, 0.10010001, 0.50000001,
#        0.10010001, 0.10010001, 0.50000001, 0.50000001, 0.50000001,
#        0.50000001, 0.10010001, 0.10010001, 0.50000001, 0.50000001,
#        0.50000001, 0.10010001, 0.50000001, 0.10010001, 0.10010001,
#        0.10010001, 0.10010001, 0.50000001, 0.50000001, 0.50000001,
#        0.10010001, 0.50000001, 0.50000001, 0.10010001, 0.50000001,
#        0.50000001, 0.10010001, 0.50000001, 0.50000001, 0.10010001,
#        0.10010001, 0.50000001, 0.50000001, 0.50000001, 0.10010001,
#        0.50000001, 0.50000001, 0.50000001, 0.50000001, 0.50000001,
#        0.10010001, 0.10010001, 0.50000001, 0.50010001, 0.50000001,
#        0.50000001, 0.50000001, 0.50000001, 0.10010001, 0.50000001])

# %%
res = joblib.load("../results/risk_slim_3/risk_bank_2-rminmax-0.pkl")
(res['linsep_results'][0]['w'] != 0).sum()
# Out:
# 14

# %%
df[df['dataset'] == 'risk_twogauss_cont-2000-1.0']

# %%
dset_curve = {}
dset_ori_curve = {}
df = display_results(LinSepBBMExperiments, '../results/lin_sep_bbm', ['n_samples', 'linsep_results'])
for i, d in df.iterrows():
    cs = [None, 1e-6, 1e-4, 1e-2, 1e-0, 1e2, 1e4, 1e6, 1e8, 1e10]
    c_n_examples = {}
    for c in cs:
        for ent in d['linsep_results']:
            if ent['c'] == c:
                break
        c_n_examples.setdefault(c, []).append(ent['n_trn_samples'])

    n_samples = []
    for c in cs:
        n_samples.append(c_n_examples[c])
    n_samples = np.asarray(n_samples).reshape(-1)

    if 'dif_depth' in d["linsep_results"][n_samples[1:].argmax()]:
        temp = np.asarray([data['tst acc'] for data in d["linsep_results"][n_samples[1:].argmax()]['dif_depth'] if data])
        curve = np.zeros(100)
        curve[:len(temp)] = temp
        curve[len(temp):] = temp[-1]
        dset_curve.setdefault(d['dataset'], []).append(curve)

        temp = np.asarray([data['tst acc'] for data in d["linsep_results"][0]['dif_depth'] if data])
        curve = np.zeros(100)
        curve[:len(temp)] = temp
        curve[len(temp):] = temp[-1]
        dset_ori_curve.setdefault(d['dataset'], []).append(curve)

        #d["linsep_results"][n_samples[1:].argmax()]['learned_model']

# %%
for k, v in dset_curve.items():
    plt.title(k, fontsize=fontsize)
    #plt.plot(np.mean(v, axis=0), label="lin sep")
    #plt.plot(np.mean(dset_ori_curve[k], axis=0), label="ori")
    plt.errorbar(x=np.arange(100), y=np.mean(dset_ori_curve[k], axis=0), yerr=scipy.stats.sem(dset_ori_curve[k], axis=0), label="ori")
    plt.xlabel('# weak learners', fontsize=fontsize)
    plt.ylabel('test accuracy', fontsize=fontsize)
    #plt.legend(fontsize=fontsize)
    plt.tight_layout()
    plt.savefig(f"./figs/bbm_acc_number/{k}.png")
    plt.close()

# %%
for i, d in df.iterrows():
    d["linsep_results"][n_samples[1:].argmax()]['learned_model']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-a7be4c479c9c> in <module>
#       1 for i, d in df.iterrows():
# ----> 2     d["linsep_results"][n_samples[1:].argmax()]['learned_model']
#
# KeyError: 'learned_model'
